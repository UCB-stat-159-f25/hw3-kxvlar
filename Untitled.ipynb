# %%
from ligotools import readligo as rl
from ligotools import utils
print(dir(utils))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 2
#       1 from ligotools import readligo as rl
# ----> 2 from ligotools import utils
#       3 print(dir(utils))
#
# File ~/hw3-kxvlar/ligotools/utils.py:6
#       3 from scipy.io import wavfile
#       4 import matplotlib.pyplot as plt
# ----> 6 from ligotools.utils import whiten, write_wavfile, reqshift, plot_psd
#
# ImportError: cannot import name 'whiten' from partially initialized module 'ligotools.utils' (most likely due to a circular import) (/home/jovyan/hw3-kxvlar/ligotools/utils.py)
